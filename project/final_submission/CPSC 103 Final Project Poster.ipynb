# %% [markdown]
# # CPSC103 Final Project Poster

# %% [markdown]
# ### Overview

# %% [markdown]
# **Big Question**: What is the average polling score of each major candidate from the 2016 US Presidential Election weighted
#               evenly upon statewide and nationwide polls?

# %% [markdown]
# Data obtained from a CSV file from Kaggle

# %% [markdown]
# Why is this interesting?
#
# 1. Being able to analyze data, manage data
# 2. Highly related to statistics
# 3. Provides an opportunity to feel the everyday life of a data analyst

# %% [markdown]
# ### Applying Systematic Program Design to the Problem

# %% [markdown]
# 1. Counter the top-level problem first, then counter the low-level problems, also known as a top-down approach
# 2. While thinking through the top-level problem, identify the step-by-step process to determine helper functions and low-level problems
#
# Top-down approach was applied to have a better picture of the overall problem.

# %% [markdown]
# ### How Was the Problem Solved

# %% [markdown]
# 1. Through the use of a top-down approach, problem solving went from building more complicated functions to simpler functions
#    to obtain the final results
# 2. Step-By-Step:
# ![Screenshot%202023-12-08%20092117.png](attachment:Screenshot%202023-12-08%20092117.png)

# %% [markdown]
# ![Screenshot%202023-12-08%20092223.png](attachment:Screenshot%202023-12-08%20092223.png)

# %% [markdown]
# ![Screenshot%202023-12-08%20092643.png](attachment:Screenshot%202023-12-08%20092643.png)

# %% [markdown]
# ### Challenges

# %% [markdown]
# The most difficult part of the project was to brainstorm all possible test cases.
# At this point, it completely depends on how good your imagination is and often times there are too many possible cases so it is difficult to manage
