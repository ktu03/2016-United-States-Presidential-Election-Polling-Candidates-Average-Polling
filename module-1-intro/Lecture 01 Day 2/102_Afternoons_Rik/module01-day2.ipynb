# %%
# You must run this cell once before you run any of the other cells in this file

# Needed (once per notebook) to enable incredible cs103 powers!!
from cs103 import *

# %% [markdown]
# # CPSC 103 - Systematic Program Design
# # Module 01 Day 2
# Rik Blok, with thanks to Ian Mitchell and Giulia Toti
#
# ---

# %% [markdown]
# # Reminders
# - this Wed-Fri: Module 1 Tutorial Attendance
# - Mon: Module 2: Pre-Lecture Assignment
# - Mon: Syllabus Quiz
# - Mon: Module 1 (Intro): Worksheet
# - Wed: Module 1 (Intro): Code Review
# - Wed: Module 1 (Intro): Tutorial Submission
# - next Wed-Fri: Module 2 Tutorial Attendance
#
# See your Canvas calendar (https://canvas.ubc.ca/calendar) for details.
#
# ---

# %% [markdown]
# # Module 1: Learning Goals
#
# At the end of this module, you will be able to:
#
# - Write statements that operate on primitive data including numbers, strings and booleans.
# - Write variable definitions and function definitions.
# - Write out the step-by-step evaluation of simple statements including function calls.
# - Use Jupyter notebooks to run Python code.
#
# ---

# %% [markdown]
# <img style="float: right; width:10%" src="https://lthub.ubc.ca/files/2020/07/iClicker-Cloud-Logo.png">
#
# # iClicker check-in
# How are you doing?  Any trouble keeping up?
#
# <!-- formatting: add two spaces at end of line to force linebreak -->
#   A. 💪 Easy-peasy... you can go faster
#   B. 👍 Yup, I got this
#   C. 😕 I might have missed a bit here or there
#   D. 😟 Hmm, something's not working right
#   E. 😵 I have no idea what's going on
#
# ---

# %% [markdown]
# # Date facts
#
# Let's check some fun facts that happened on a date. We will use the the API http://numbersapi.com/. Think of an API a way for us to communicate with another computer to get the information we need.
#
# First, we have to `import` the `date_fact` library, that contains the code to use the API:

# %%
# This indicates we are going to use some code from the date_fact.py file
from date_fact import *

# %% [markdown]
# ---
#
# # Function signatures
#
# To use any supplied function we need to know its *signature*, or its...
# - name,
# - arguments, and
# - return value.
#
# The code inside the file `date_fact.py` gives us the following functions:
#
# - `get_date_fact(month: int, day: int) -> str`
#
#
# - `get_number_fact(number: int) -> str`
#
#
# - `get_year_fact(year: int) -> str`

# %%
# Get some trivia from the year you were born!

# First, take a look at the names of the functions. Out of the three
# functions listed above, which one do you think we should use?

# Now, look at the signature of the function you have chosen.
# What kind of information does it ask for (hint: what parameters are listed
# in the signature)?

# Try to call (i.e., use) the function!

# %% [markdown]
# # Include the year
# Notice how the output from the function does not include the year.  The argument does not necessarily need to be included in the output of a function.
#
# Without changing the function itself, let's change the cell's output to display a sentence that also states the year, like
# > In 2000, ...

# %% [markdown]
# <div class="alert alert-info">
#
# ### ℹ️ Mixing data types
#
# - Recall, we've seen a few different primitive types: `int`, `float`, and `str`
# - Different types don't always mix:
#     - ✅ `1 + 1 ` ⇒ `2`
#     - ✅ `'1' + '1'` ⇒ `'11'`
#     - ⛔ `'1' + 1` ⇒ Syntax error
# - You might find the `str` function useful.  It converts a number into a string
#
# </div>
#
# ---

# %% [markdown]
# # Changing things up
# What happens if we want to find facts from another year?
#
# Is there an easier way to change the value of the year without having to remember all the places the year appeared in?

# %%
year = 2000

# Rewrite your expression above so that it uses the variable `year`

# %% [markdown]
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample solution (For later.  Don't peek if you want to learn 🙂)</summary>
#
# ```python
# year = 1980
#
# 1 + 1     # 2    ✓
# '1' + '1' # '11' ✓
# # '1' + 1 # nononono
#
# "In " + str(year) + ", " + get_year_fact(year) + "."
# ```
#
# </details>
#
# ---

# %% [markdown]
# # What happened on your date of birth?
# Write some code to find an event that happened on your birth date (month and day). Follow the same steps as before.
#
# 1. Take a look at the names of the functions. Out of the three functions [listed above](#Function-signatures), which one should we use?
# 2. Take a look at the signature. What pieces of information is the function asking for? What kinds of data types are they?
# 3. Try to call the function!

# %% [markdown]
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample solution (For later.  Don't peek if you want to learn 🙂)</summary>
#
# ```python
# get_date_fact(9, 16)
# ```
#
# </details>
#
# ---

# %% [markdown]
# # Include the month and day
# Now, try to include information about your date of birth before the fun fact in a sentence! For example, if your birthday was on *September 16* and the fact produced for this particular day is
# > 'the Cape Verde Islands, Mozambique, and Sao Tome and Principe join the United Nations'
#
# then your code should produce
# > 'On 9/16 the Cape Verde Islands, Mozambique, and Sao Tome and Principe join the United Nations.'
#
# Can you do this in a way that makes it easy for us to change the values for the birth month and day?

# %% [markdown]
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample solution (For later.  Don't peek if you want to learn 🙂)</summary>
#
# ```python
# month = 9
# day   = 16
#
# 'On ' + str(month) + '/' + str(day) + ' ' + get_date_fact(month, day) + '.'
# ```
#
# </details>
#
# ---

# %% [markdown]
# # Improving on greatness
# Let's make the output better.
#
# Instead of using numbers to describe a month, let's use the month's abbreviated (3- or 4-letter) name.  For example, instead of '9/16' let's write 'Sept 16'.
#
# For this task we'll use the `if/elif/else` statement, first introduced in question 16 of the Module 1 (Intro) worksheet, due on Monday.
#
# <div class="alert alert-info">
#
# ### ℹ️ `elif` keyword
#
# The Python keyword `elif` stands for "else if" – it only gets checked if none of the previous condition(s) were True.
#
# </div>

# %% [markdown]
# <img style="float: right; width:10%" src="https://lthub.ubc.ca/files/2020/07/iClicker-Cloud-Logo.png">
#
# # iClicker question: `if/elif`
#
# <div style="width: 100%; display: flex; justify-content: space-between;">
#
# <div style="float: left; width: 30%">
#
# Consider the program to the right.  What does it produce when it is run?
#
# <ol style="list-style-type:upper-alpha">
#     <li>"Initial value"</li>
#     <li>"Bigger than zero!"</li>
#     <li>"Bigger than minus 10."</li>
#     <li>"Very small!"</li>
#     <li>Something else</li>
# </ol>
#
# </div>
#
# <div style="float: right; width: 70%">
#
# ```python
# output = "Initial value"
# number = -23
# if number > 0:
#     output = "Bigger than zero!"
# elif number > -10:
#     output = "Bigger than minus 10."
# elif number > -20:
#     output = "Very small!"
# output
# ```
#
# </div>
#
# </div>
#
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Hint (for your review after class)</summary>
#
# Let's [trace the code](https://pythontutor.com/visualize.html#code=output%20%3D%20%22Initial%20value%22%0Anumber%20%3D%20-23%0Aif%20number%20%3E%200%3A%0A%20%20%20%20output%20%3D%20%22Bigger%20than%20zero!%22%0Aelif%20number%20%3E%20-10%3A%0A%20%20%20%20output%20%3D%20%22Bigger%20than%20minus%2010.%22%0Aelif%20number%20%3E%20-20%3A%0A%20%20%20%20output%20%3D%20%22Very%20small!%22%0Aoutput&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false) to see what happens.
#
# </details>
#
# ---

# %%
# Enter your birth date (month and day)
month = 9
day   = 16

# Construct a sentence that reports your birth date 
# with the name of the month and a fact about that day.

# %% [markdown]
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample solution (For later.  Don't peek if you want to learn 🙂)</summary>
#
# ```python
# # Enter your birth date (month and day)
# month = 9
# day   = 16
#
# # Construct a sentence that reports your birth date
# # with the name of the month and a fact about that day.
# if month == 1:
#     month_name = 'Jan'
# elif month == 2:
#     month_name = 'Feb'
# elif month == 3:
#     month_name = 'Mar'
# elif month == 4:
#     month_name = 'Apr'
# elif month == 5:
#     month_name = 'May'
# elif month == 6:
#     month_name = 'June'
# elif month == 7:
#     month_name = 'July'
# elif month == 8:
#     month_name = 'Aug'
# elif month == 9:
#     month_name = 'Sept'
# elif month == 10:
#     month_name = 'Oct'
# elif month == 11:
#     month_name = 'Nov'
# elif month == 12:
#     month_name = 'Dec'
#
# 'On ' + month_name + ' ' + str(day) + ' ' + get_date_fact(month, day) + '.'
# ```
#
# </details>
#
# ---

# %% [markdown]
# # How to handle invalid data?
#
# What if the user enters an invalid number for the month (not 1..12)?  How should we handle that case?
#
# Let's go back up to the code cell above and revise our code to handle this special case.
#
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample solution (For later.  Don't peek if you want to learn 🙂)</summary>
#
# ```python
# # Enter your birth date (month and day)
# month = 9
# day   = 16
#
# # Design a sentence that reports your birth date with the name of the month and a fact about that day.
# if month == 1:
#     month_name = 'Jan'
# elif month == 2:
#     month_name = 'Feb'
# elif month == 3:
#     month_name = 'Mar'
# elif month == 4:
#     month_name = 'Apr'
# elif month == 5:
#     month_name = 'May'
# elif month == 6:
#     month_name = 'June'
# elif month == 7:
#     month_name = 'July'
# elif month == 8:
#     month_name = 'Aug'
# elif month == 9:
#     month_name = 'Sept'
# elif month == 10:
#     month_name = 'Oct'
# elif month == 11:
#     month_name = 'Nov'
# elif month == 12:
#     month_name = 'Dec'
# else:
#     month_name = 'Invalid month'
#
# 'On ' + month_name + ' ' + str(day) + ' ' + get_date_fact(month, day) + '.'
# ```
#
# </details>
#
# ---

# %% [markdown]
# # Writing your own functions
#
# So far, we have learned that functions are pretty great!
# - Code re-use: They allow us to perform an action without having to rewrite the code every time
# - Abstraction: We can use other people's functions without knowing how they work, just what arguments they need and what they return
#
# Naturally, you will want to be able to write your own functions.
#
# ---

# %% [markdown]
# # Checking the sign
#
# **Problem:** Check if a number is positive or negative.
#
# **Steps:**
# 1. Assign a number to a new variable.
# 2. Create a blank string variable `output`.
# 3. Fill the `output` with text that indicates whether `number` is positive or negative.
# 4. Display the contents of `output`.

# %%
# Step 1. Assign a number to a new variable.


# Step 2. Create a blank string variable output.


# Step 3. Fill the output with text that indicates whether 
# number is positive or negative.


# Step 4. Display the contents of output.

# %% [markdown]
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample solution (For later.  Don't peek if you want to learn 🙂)</summary>
#
# ```python
# # Step 1. Assign a number to a new variable.
# number = 0
#
# # Step 2. Create a blank string variable output.
# output = ''
#
# # Step 3. Fill the output with text that indicates whether number is positive or negative.
# if number > 0:
#     output = 'Positive'
# else:
#     output = 'Negative'
#
# # Step 4. Display the contents of output.
# output
# ```
#
# </details>
#
# ---

# %% [markdown]
# ## Special cases
#
# You should always consider special cases you might need to handle.
#
# Are there any special cases for this problem?  How should we handle them?  Let's implement that in our code, above.

# %% [markdown]
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample solution (For later.  Don't peek if you want to learn 🙂)</summary>
#
# ```python
# # Step 1. Assign a number to a new variable.
# number = 0
#
# # Step 2. Create a blank string variable output.
# output = ''
#
# # Step 3. Fill the output with text that indicates whether number is positive or negative.
# if number > 0:
#     output = 'Positive'
# elif number < 0:
#     output = 'Negative'
# else:
#     output = 'Zero'
#
# # Step 4. Display the contents of output.
# output
# ```
#
# </details>
#
# ---

# %% [markdown]
# # Let's do it again, but make a function
#
# ![module01-worker.gif](attachment:module01-worker.gif)
#
# ---

# %% [markdown]
# # Checking the sign (refactored)
#
# **Problem:** Check if a number is positive or negative.
#
# **Task:**
#
# Write a function that:
# 1. Takes a number as an argument.
# 2. Creates a local string variable `output`.
# 3. Fills the `output` with text that indicates whether `number` is positive or negative.
# 4. Returns the contents of `output`.

# %% [markdown]
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample solution (For later.  Don't peek if you want to learn 🙂)</summary>
#
# ```python
# def sign_of(number):
#     if number > 0:
#         output = 'Positive'
#     elif number < 0:
#         output = 'Negative'
#     else:
#         output = 'Zero'
#     return output
# ```
#
# </details>
#
# ---

# %% [markdown]
# # Things to notice
#
# - The statements contained within the function (its *body*) are all indented.
# - The argument type (`int`) and function return type (`str`) aren't required here.  But we'll require them later so we're introducing them here.
# - How could we rewrite the function so that it doesn't need the local variable `output`?
#
# ---

# %% [markdown]
# Now, test our function by calling it with a few different numbers (or variables).

# %% [markdown]
# <img style="float: right; width:10%" src="https://lthub.ubc.ca/files/2020/07/iClicker-Cloud-Logo.png">
#
# # iClicker question
# Imagine you want to write a function to compute how many one-Litre cans of paint are needed to paint a wall.  Which of the following are good arguments for this function?  Select **ALL** that apply.
#
# <!-- formatting: add two spaces at end of line to force linebreak -->
#
# A. Height of the wall
# B. Width of the wall
# C. Thickness of the wall
# D. Size of a can
# E. Number of cans needed
#
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Hints (for your review after class)</summary>
#
# - The size of the can is already given in the problem.
# - The function should return the number of cans needed.
#
# </details>
#
# ---

# %% [markdown]
# <img style="float: right; width:10%" src="https://lthub.ubc.ca/files/2020/07/iClicker-Cloud-Logo.png">
#
# # iClicker question
# We want to write a function that repeats a given string.  Which of the following are correct?  Select **ALL** that apply.  Try to answer this question based on your knowledge, without running the code.
#
# <ol style="list-style-type:upper-alpha">
#     <li><code>def 2_times(thing):
#     return thing+thing</code></li>
#     <li><code>def repeat_it(string):
#     string*2</code></li>
#     <li><code>def repeat_string_once2(string):
#     return 'string' + 'string'</code></li>
#     <li><code>def repeat_string_once(string):
#     return string*2</code></li>
#     <li><code>def repeat(s):
#     new_s = s + s
#     return new_s</code></li>
# </ol>
#
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Hints (for your review after class)</summary>
#
# - Python identifiers (e.g., variable and function names) must begin with a letter or an underscore
# - What do you expect will happen if you call some of these functions with numbers instead of strings?  Try it!  Were you right?
# - In option E you created a `new_s` variable in the function.  Can you access that variable after calling the function?
# - Option E contains two statements in the function.  Notice they both have the same indentation.
#
# </details>
#
# ---

# %%
# Reproduce those functions here and try calling them!  (Watch your indentation!)

# %% [markdown]
# ---
#
# <img style="float: right; width:10%" src="https://lthub.ubc.ca/files/2020/07/iClicker-Cloud-Logo.png">
#
# # iClicker check-in
# How are you doing?  Any trouble keeping up?
#
# <!-- formatting: add two spaces at end of line to force linebreak -->
#   A. 💪 Easy-peasy... you can go faster
#   B. 👍 Yup, I got this
#   C. 😕 I might have missed a bit here or there
#   D. 😟 Hmm, something's not working right
#   E. 😵 I have no idea what's going on
#
# ---

# %% [markdown]
# # Extra content

# %% [markdown]
# # Swapping variables
# Let's get more familiar with how variables store data.  In Computer Science we often need to swap the contents of two variables, `x` and `y`.  So, after the swap, `x` now holds what was originally in `y`, and vice versa.
#
# How can we do that?

# %% [markdown]
# <img style="float: right; width:10%" src="https://lthub.ubc.ca/files/2020/07/iClicker-Cloud-Logo.png">
#
# # iClicker question: Swapping
#
# Let's say we begin with two variables assigned values `x = 5` and `y = 10`.  Which of the following programs will successfully swap the variables so their final values are `x = 10` and `y = 5`?  Select **ALL** that apply. [iClicker: Change poll type to Multiple Answer]
#
# <div style="width: 100%; display: flex; justify-content: space-between;">
#
# <div style="float: left; width: 50%">
#
# ### (A)
#
# ```python
# x = y
# y = x
# ```
#
# </div>
#
# <div style="float: left; width: 50%">
#
# ### (B)
#
# ```python
# oldx = x
# oldy = y
# x = oldy
# y = oldx
# ```
#
# </div>
#
# </div>
#
# <div style="width: 100%; display: flex; justify-content: space-between;">
#
# <div style="float: left; width: 50%">
#
# ### (C)
#
# ```python
# oldx = x
# x = y
# y = oldx
# ```
#
# </div>
#
# <div style="float: left; width: 50%">
#
# ### (D)
#
# ```python
# oldx = x
# y = oldx
# x = y
# ```
#
# </div>
#
# </div>
#
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Hint (for your review after class)</summary>
#
# The sequence of commands matters.  We need to make sure we don't lose track of the original `x` and `y` values while we're swapping them.
#
# </details>
#
# ---

# %% [markdown]
# <img style="float: right; width:10%" src="https://lthub.ubc.ca/files/2020/07/iClicker-Cloud-Logo.png">
#
# # iClicker question: `sqrt`
# Recall question 10 from the pre-class reading quiz:
# ```python
# x = 9
# sqrt(9) # a built-in math function that returns the square root of its input
# ```
# What is the value of `x` after the function call?  (If it helps, you can add the code to the cell below and run it.)
#
# <!-- formatting: add two spaces at end of line to force linebreak -->
#   A. 9
#   B. 3
#   C. 3.0
#   D. Something else
#
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Hints (for your review after class)</summary>
#
# - Notice, we want the value of `x`, not the result of the expression.
# - What's the purpose of the `from math import *` statement below?
#
# </details>

# %%
from math import *
