# %%
from cs103 import * # needed (once per notebook) to enable incredible cs103 powers!!

# %% [markdown]
# # CPSC 103 - Systematic Program Design
# # Module 02 (HtDF) Day 1
# Rik Blok, with thanks to Ian Mitchell and Giulia Toti
#
# ---

# %% [markdown]
# # Reminders
# - Wed: Module 1 (Intro): Code Review
# - Wed: Module 1 (Intro): Tutorial Submission
# - this Wed-Fri: Module 2 Tutorial Attendance
# - Mon: Module 3: Pre-Lecture Assignment
# - Mon: Module 2 (HtDF): Worksheet
#
# See your Canvas calendar (https://canvas.ubc.ca/calendar) for details.
#
# ---

# %% [markdown]
# # Exam practice exercises - by module
# After each module: self-assess and practice for exams at https://canvas.ubc.ca/courses/123409/pages/extra-exercises-written
#
# Designed to help you assess your exam preparation. For a more accurate assessment:
# - practice on paper, to better simulate exam conditions
# - practice without distractions and interruptions
# - time yourself
# - do not use any notes or other resources that would not be available during the real exam
# - only check the solution when you are done with all the exercises
#
# ---

# %% [markdown]
# # Module learning goals
#
# At the end of this module, you will be able to:
#
# - use the How to Design Functions (HtDF) recipe to design functions that operate on primitive data.
# - read a complete function design and identify its different elements.
# - evaluate the elements of a function design for clarity, simplicity, and consistency with each other.
# - evaluate an entire design for how well it solves the given problem.
# - explain the intended purpose of the HtDF recipe's steps in a way that generalizes to other design problems.
#
# ---

# %% [markdown]
# <img style="float: right; width:10%" src="https://lthub.ubc.ca/files/2020/07/iClicker-Cloud-Logo.png">
#
# # iClicker question
#
# You want a program that will display the appropriate response in these cases:
# - "That is very warm" if `temp` > 30,
# - "That is warm" if `temp` is in the range [20,30] (inclusive),
# - "That is cool", otherwise.
#
# Which of the following is correct, assuming `temp` has been assigned some numerical value?
#
# <div style="width: 100%; display: flex; justify-content: space-between;">
#
# <div style="float: left; width: 50%">
#
# ### (A)
#
# ```python
# out = "That is "
# if temp > 30:
#     out = out + "very "
# elif temp >= 20:
#     out = out + "warm"
# else:
#     out = out + "cool"
# out
# ```
#
# </div>
#
# <div style="float: right; width: 50%">
#
# ### (B)
#
# ```python
# out = "That is "
# if temp > 30:
#     out = out + "very "
# if temp >= 20:
#     out = out + "warm"
# else:
#     out = out + "cool"
# out
# ```
#
# </div>
#
# </div>
#
# <div style="width: 100%; display: flex; justify-content: space-between;">
#
# <div style="float: left; width: 50%">
#
# ### (C) Both
#
# </div>
#
# <div style="float: right; width: 50%">
#
# ### (D) Neither
#
# </div>
#
# </div>
#
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Hint (for your review after class)</summary>
#
# - The programs are identical except for one word.
# - What does each produce if `temp = 31`?
#
# </details>

# %% [markdown]
# # About good programming
#
# > ...programming differs from good programming like crayon sketches in a diner from oil paintings in a museum.
# > – [How to Design Programs, Second Edition](https://htdp.org/2022-8-7/Book/part_preface.html)
#
# <div style="float: left; width: 45%">
#     <a title="Aaron Burden aaronburden, CC0, via Wikimedia Commons" href="https://commons.wikimedia.org/wiki/File:Crayons_beside_child_coloring_(Unsplash).jpg"><img alt="Crayons beside child coloring (Unsplash)" src="https://upload.wikimedia.org/wikipedia/commons/thumb/5/50/Crayons_beside_child_coloring_%28Unsplash%29.jpg/512px-Crayons_beside_child_coloring_%28Unsplash%29.jpg"></a>
# </div>
# <div style="float: right; width: 45%">
# <a title="Leonardo da Vinci, Public domain, via Wikimedia Commons" href="https://commons.wikimedia.org/wiki/File:Mona-lisa_1.jpg"><img alt="Mona-lisa 1" src="https://upload.wikimedia.org/wikipedia/commons/b/b4/Mona-lisa_1.jpg"></a>
# </div>

# %% [markdown]
# # After this course...
#
# <div style="width: 100%; display: flex; justify-content: space-between;">
#
# <div style="float: left; width: 45%">
#     <p>Maybe you won't be like him (yet!)...</p>
#     <a title="Leonardo da Vinci, Public domain, via Wikimedia Commons" href="https://commons.wikimedia.org/wiki/File:Leonardo_self.jpg"><img alt="Leonardo self" src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Leonardo_self.jpg/256px-Leonardo_self.jpg"></a>
# </div>
# <div style="float: right; width: 45%">
#     <p>...but you could be like them!</p>
#     <a title="David Shankbone, CC BY 3.0 &lt;https://creativecommons.org/licenses/by/3.0&gt;, via Wikimedia Commons" href="https://commons.wikimedia.org/wiki/File:Jonas_Burgert_painting_admirers_at_Denver_Museum_of_Contemporary_Art.JPG"><img alt="Jonas Burgert painting admirers at Denver Museum of Contemporary Art" src="https://upload.wikimedia.org/wikipedia/commons/thumb/9/9c/Jonas_Burgert_painting_admirers_at_Denver_Museum_of_Contemporary_Art.JPG/512px-Jonas_Burgert_painting_admirers_at_Denver_Museum_of_Contemporary_Art.JPG"></a>
# </div>
#
# </div>
#
# ---

# %% [markdown]
# # How to Design Functions (HtDF) recipe
#
# The HtDF recipe consists of the following steps:
# 1. Write the **s**tub, including signature and purpose
# 2. Define **e**xamples
# 3. Write the **t**emplate
# 4. **I**mplement the function body
# 5. **T**est and debug until correct
#
# <div class="alert alert-info">
#
# ### ℹ️ Q: How to Design Functions?  A: SETIT!
#
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">SETIT stands for...</summary>
#
# 1. **S**tub
# 2. **E**xamples
# 3. **T**emplate
# 4. **I**mplement
# 5. **T**est
#
# </details>
#
# </div>
#
# ---

# %% [markdown]
# # Step 1 Write the <u>S</u>tub, including signature and purpose
#
# <details class="alert alert-success" style="float: right; margin-left: 1em;"><summary style="display:list-item">Jump to...</summary>
#
# * 🡲 Step 1 Stub
# * 🡳 [Step 2 Examples](#Step-2-Define-Examples)
# * 🡳 [Step 3 Template](#Step-3-Write-the-Template)
# * 🡳 [Step 4 Implement](#Step-4-Implement-the-function-body)
# * 🡳 [Step 5 Test](#Step-5-Test-and-debug-until-correct)
#
# </details>
#
# *Stub* - a temporary placeholder for some yet-to-be-developed code
#
# Three substeps to write the stub:
#
# 1a. [Signature](#Step-1a:-Signature)
# 1b. [Purpose](#Step-1b:-Purpose)
# 1c. [Stub return](#Step-1c:-Stub-return)
#
# ---

# %% [markdown]
# # Step 1a: Signature
#
# <details class="alert alert-success" style="float: right; margin-left: 1em;"><summary style="display:list-item">Jump to...</summary>
#
# * 🡱 [Step 1 Stub](#Step-1-Write-the-Stub,-including-signature-and-purpose)
# * 🡳 [Step 2 Examples](#Step-2-Define-Examples)
# * 🡳 [Step 3 Template](#Step-3-Write-the-Template)
# * 🡳 [Step 4 Implement](#Step-4-Implement-the-function-body)
# * 🡳 [Step 5 Test](#Step-5-Test-and-debug-until-correct)
#
# </details>
#
# Defines the **input type(s) and output type** for your function.  It is also when you give a **name** to your function and to the parameters.  Names should be **all lower case**, with underscore (`_`) separating words.
#
# Example: Design a program that returns the double of a given number.

# %% [markdown]
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample solution (For later.  Don't peek if you want to learn 🙂)</summary>
#
# ```python
# @typecheck
# def double(n: float) -> float:
# ```
#
# </details>
#
# ## Aside: @typecheck
# What does `@typecheck` do?  Let's find out!

# %%
help(typecheck)

# %% [markdown]
# We will annotate every function we define with `@typecheck`.  Let's start with our example function above.
#
# ---

# %% [markdown]
# # Step 1b: Purpose
#
# <details class="alert alert-success" style="float: right; margin-left: 1em;"><summary style="display:list-item">Jump to...</summary>
#
# * 🡱 [Step 1 Stub](#Step-1-Write-the-Stub,-including-signature-and-purpose)
# * 🡳 [Step 2 Examples](#Step-2-Define-Examples)
# * 🡳 [Step 3 Template](#Step-3-Write-the-Template)
# * 🡳 [Step 4 Implement](#Step-4-Implement-the-function-body)
# * 🡳 [Step 5 Test](#Step-5-Test-and-debug-until-correct)
#
# </details>
#
# The purpose statement describes what the function will return. It is written in triple quotes at the top of a function's body and documents the function.
#
# Example: Design a program that returns the double of a given number.

# %% [markdown]
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample solution (For later.  Don't peek if you want to learn 🙂)</summary>
#
# ```python
# @typecheck
# def double(n: float) -> float:
#     """
#     Returns n doubled
#     """
# ```
#
# </details>
#
# ## Aside: Docstrings
#
# - Triple quotes denote a *multiline string*, a string that can contain linebreaks
# - Just a literal string.  Expression is evaluated but discarded
# - When placed immediately below a function definition, treated as documentation or *docstring*
#
# Example:

# %%
# display documentation for our function
help(...)

# %% [markdown]
# Note that I could also have written the documentation in a comment (`# ...`).  But then `help` would not have displayed it.
#
# We will write a purpose statement inside a docstring at the top of every function we define.
#
# ---

# %% [markdown]
# # Step 1c: Stub return
#
# <details class="alert alert-success" style="float: right; margin-left: 1em;"><summary style="display:list-item">Jump to...</summary>
#
# * 🡱 [Step 1 Stub](#Step-1-Write-the-Stub,-including-signature-and-purpose)
# * 🡳 [Step 2 Examples](#Step-2-Define-Examples)
# * 🡳 [Step 3 Template](#Step-3-Write-the-Template)
# * 🡳 [Step 4 Implement](#Step-4-Implement-the-function-body)
# * 🡳 [Step 5 Test](#Step-5-Test-and-debug-until-correct)
#
# </details>
#
# The stub must return a value of the right type. It doesn't need to be correct, any value from the right type will do  The stub return must also be commented as such, with `# stub`.
#
# Example: Design a program that returns the double of a given number.

# %% [markdown]
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample solution (For later.  Don't peek if you want to learn 🙂)</summary>
#
# ```python
# @typecheck
# def double(n: float) -> float:
#     """
#     Returns n doubled
#     """
#     return 0.0 # stub
# ```
#
# </details>
#
# We will add a stub return to every function we define.
#
# ---

# %% [markdown]
# # Step 2 Define <u>E</u>xamples
#
# <details class="alert alert-success" style="float: right; margin-left: 1em;"><summary style="display:list-item">Jump to...</summary>
#
# * 🡱 [Step 1 Stub](#Step-1-Write-the-Stub,-including-signature-and-purpose)
# * 🡲 Step 2 Examples
# * 🡳 [Step 3 Template](#Step-3-Write-the-Template)
# * 🡳 [Step 4 Implement](#Step-4-Implement-the-function-body)
# * 🡳 [Step 5 Test](#Step-5-Test-and-debug-until-correct)
#
# </details>
#
# Write *at least* one example of a call to the function and the result that the function is expected to return.
#
# We will use the following notation (using functions from the `cs103` library) to write our examples:
#
# ```python
# ...
#     return 0 # stub
#
# start_testing()
#
# expect( ... , ... ) # an example
# expect( ... , ... ) # another example
# ...
#
# summary()
# ```
#
# Example: Design a program that returns the double of a given number.

# %% [markdown]
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample solution (For later.  Don't peek if you want to learn 🙂)</summary>
#
# ```python
# ...
#     return 0 # stub
#
# start_testing()
# expect(double(0), 2 * 0)
# expect(double(-2.1), 2 * -2.1)
# expect(double(10.11), 2 * 10.11)
# summary()
# ```
#
# </details>
#
# We will add test cases to cover all conditions we can think of for every function we define.
#
# ---

# %% [markdown]
# # Step 3 Write the <u>T</u>emplate
#
# <details class="alert alert-success" style="float: right; margin-left: 1em;"><summary style="display:list-item">Jump to...</summary>
#
# * 🡱 [Step 1 Stub](#Step-1-Write-the-Stub,-including-signature-and-purpose)
# * 🡱 [Step 2 Examples](#Step-2-Define-Examples)
# * 🡲 Step 3 Template
# * 🡳 [Step 4 Implement](#Step-4-Implement-the-function-body)
# * 🡳 [Step 5 Test](#Step-5-Test-and-debug-until-correct)
#
# </details>
#
# Comment out the body of the stub and copy the body of the template from the data definition to the function design. In case there is no data definition, just copy all parameters.
#
# <div class="alert alert-warning">
#
# ## ⚠️ Data definition
#
# We'll learn about data definition later in the course.  So the instructions above may not make much sense to you yet.  For now, we'll "just copy all parameters".
#
# We want you to get in the habit of writing a template.  It will become **very** useful later.
#
# </div>
#
# Example: Design a program that returns the double of a given number.

# %% [markdown]
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample solution (For later.  Don't peek if you want to learn 🙂)</summary>
#
# ```python
# @typecheck
# def double(n: float) -> float:
#     """
#     Returns n doubled
#     """
#     # return 0 # stub
#     return ...(n) # template
#
# start_testing()
# expect(double(0), 2 * 0)
# expect(double(-2.1), 2 * -2.1)
# expect(double(10.11), 2 * 10.11)
# summary()
# ```
#
# </details>
#
# We will write a function template for every function we define.
#
# ---

# %% [markdown]
# ## Aside: Ellipsis (`...`)
#
# Ellipsis (`...`) can be used as a placeholder for future code.  Skipped over when run.  Useful for testing.
#
# Example:

# %%
def future_function_1():
    # Nonfunctional but will run
    ...

def future_function_2():
    # Will throw error

# %% [markdown]
# ---
#
# # Step 4 <u>I</u>mplement the function body
#
# <details class="alert alert-success" style="float: right; margin-left: 1em;"><summary style="display:list-item">Jump to...</summary>
#
# * 🡱 [Step 1 Stub](#Step-1-Write-the-Stub,-including-signature-and-purpose)
# * 🡱 [Step 2 Examples](#Step-2-Define-Examples)
# * 🡱 [Step 3 Template](#Step-3-Write-the-Template)
# * 🡲 Step 4 Implement
# * 🡳 [Step 5 Test](#Step-5-Test-and-debug-until-correct)
#
# </details>
#
# Complete the function body by filling in the template, note that you have a lot of information written already.  Remember to comment out the template.
#
# Example: Design a program that returns the double of a given number.

# %% [markdown]
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample solution (For later.  Don't peek if you want to learn 🙂)</summary>
#
# ```python
# @typecheck
# def double(n: float) -> float:
#     """
#     Returns n doubled
#     """
#     # return 0 # stub
#     # return ...(n) # template
#     return n * 2
#
# start_testing()
# expect(double(0), 2 * 0)
# expect(double(-2.1), 2 * -2.1)
# expect(double(10.11), 2 * 10.11)
# summary()
# ```
#
# </details>
#
# <div class="alert alert-warning">
#
# ### ⚠️ Why the stub and template?
#
# You may wonder why we've written the stub and template, only to comment them out immediately.  The reasons have to do with good program design and will become clear later in the course.
#
# </div>
#
# ---

# %% [markdown]
# # Step 5 <u>T</u>est and debug until correct
#
# <details class="alert alert-success" style="float: right; margin-left: 1em;"><summary style="display:list-item">Jump to...</summary>
#
# * 🡱 [Step 1 Stub](#Step-1-Write-the-Stub,-including-signature-and-purpose)
# * 🡱 [Step 2 Examples](#Step-2-Define-Examples)
# * 🡱 [Step 3 Template](#Step-3-Write-the-Template)
# * 🡱 [Step 4 Implement](#Step-4-Implement-the-function-body)
# * 🡲 Step 5 Test
#
# </details>
#
# You should run and correct your function until all tests pass.
#
# <div class="alert alert-info">
#
# ### ℹ️ Terminology
#
#
# <dl>
#     <dt>[Bug](https://en.wikipedia.org/wiki/Software_bug)</dt>
#     <dd>- A defect or problem that prevents correct operation</dd>
#     <dt>[Debugging](https://en.wikipedia.org/wiki/Debugging)</dt>
#     <dd>- The process of finding and resolving bugs</dd>
# </dl>
#
# <a title="Courtesy of the Naval Surface Warfare Center, Dahlgren, VA., 1988., Public domain, via Wikimedia Commons" href="https://commons.wikimedia.org/wiki/File:First_Computer_Bug,_1945.jpg">
#
# ![module02-First_Computer_Bug,_1945_cropped.jpg](attachment:module02-First_Computer_Bug,_1945_cropped.jpg)
#
# </a>
# Moth found trapped in the Mark II Aiken Relay Calculator while it was being tested, 1947. The operators affixed the moth to the computer log, with the entry: "First actual case of bug being found". (The term "debugging" already existed.)
#
# </div>
#
# Example: Design a program that returns the double of a given number.

# %% [markdown]
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample program with bug for testing (For later.  Don't peek if you want to learn 🙂)</summary>
#
# The following code contains an error.  Testing the function with the examples will help us reason through the issue to identify and fix the bug.
#
# ```python
# @typecheck
# def double(n: float) -> float:
#     """
#     Returns n doubled
#     """
#     # return 0 # stub
#     # return ...(n) # template
#     return n ** 2
#
# start_testing()
# expect(double(0), 2 * 0)
# expect(double(-2.1), 2 * -2.1)
# expect(double(10.11), 2 * 10.11)
# summary()
# ```
#
# </details>
#
# ---

# %%
# Now that your function is fully designed and tested, 
# you can use it

# %% [markdown]
# # Questions from the pre-lecture assignment
#
# 1. What exactly is the difference between the stub and the template? What do you put in a stub return vs a template return?
#
# <details><summary>▶ Answer:</summary>
#
# - **Stub**: Placeholder.  Completes the function to make it work, with intention that we'll fix it later
# - **Template**: Helps describe what we want the function to do, how the parameters are involved, and other things that depend on the data we're using.  Benefits will become clearer when we move beyond primitive data types
# </details>
#
# 2. What is the benefit of using the HtDF recipe as opposed to just defining functions the way we learned to in Module 1? Do programmers use this recipe while working/will we find use for the recipe outside of this class?
#
# <details><summary>▶ Answer:</summary>
#
# - Step-by-step guide for how to write functions
# - Guarantees you write a function that works properly
# - Resulting code is readable.  Compare:
# ```python
# def double(n):
#     return n ** 2
# ```
#
# </details>
#
# ---

# %% [markdown]
# # Exercise: `is_palindrome` (similar to Pre-Lecture Assignment)
#
# **Problem:** Design a function that takes a string and determines whether it is a palindrome or not.  (A palindrome is a word or phrase that reads the same backwards and forwards - e.g., "level".)
#
# The first step of our HtDF recipe have already been completed below (with two possible purposes included):
# 1. Done: Write the <u>**S**</u>tub, including signature and purpose
# 2. TODO: Define <u>**E**</u>xamples
# 3. TODO: Write the <u>**T**</u>emplate
# 4. TODO: <u>**I**</u>mplement the function body
# 5. TODO: <u>**T**</u>est and debug until correct
#
# <img style="float: right; width:10%" src="https://lthub.ubc.ca/files/2020/07/iClicker-Cloud-Logo.png">
#
# ### Step 1: Write the <u>S</u>tub
#
# #### iClicker questions
#
# 1. Where is the function signature?
#    **(A)** Line 3, &nbsp; &nbsp; **(B)** Line 4, &nbsp; &nbsp; **(C)** Lines 6-12, &nbsp; &nbsp; **(D)** Line 13, &nbsp; &nbsp; **(E)** Lines 16-18
#
# <details><summary>▶ Next</summary>
#
# 2. What should the function purpose be?
#    **(A)** Lines 6-8, &nbsp; &nbsp; **(B)** Lines 10-12 &nbsp; &nbsp; **(C)** Something else
#
# <details><summary>▶ Next</summary>
#
# ### Step 2: Define <u>E</u>xamples
#
# Consider:
# - Typical cases (i.e., some that we expect to be true and false)
# - Special cases (e.g., case-sensitive?)
# - Edge cases (limiting conditions, e.g., single character?  Empty string?)
#
# <details><summary>▶ Next</summary>
#
# ### Step 3: Write the <u>T</u>emplate
#
# - Demonstrates how the data will be used
#
# <details><summary>▶ Next</summary>
#
# ### Step 4: <u>I</u>mplement the function body
#
# - Hint: Notice what the slice `[::-1]` does to a string.  (Try it! 🙂)
# - Compare returning a boolean to using `if else`
#
# <details><summary>▶ Next</summary>
#
# ### Step 5: <u>T</u>est and debug until correct
#
# </details>
# </details>
# </details>
# </details>
# </details>

# %%
# Design is_palindrome function here

@typecheck
def is_palindrome(word: str) -> bool:
    # Should the purpose be...?
    """
    return True if the word is a palindrome, and False otherwise
    """
    # Or...?
    """
    return True if the word meets our requirements
    """
    return True  # stub
    
# Starting point for any set of tests/examples:
start_testing()
expect(..., ...)
summary()

# %% [markdown]
# <details class="alert alert-info"><summary style="cursor:pointer; display:list-item">ℹ️ Sample solution (For later.  Don't peek if you want to learn 🙂)</summary>
#
# ```python
# # Design is_palindrome function here
#
# @typecheck
# def is_palindrome(word: str) -> bool:
#     """
#     return True if the word is a palindrome, and False otherwise
#     """
#     # return True  # stub
#     # return ...(word) # template
#     if word == word[::-1]:
#         return True
#     else:
#         return False
#
# # Starting point for any set of tests/examples:
# start_testing()
# expect(is_palindrome("racecar"), True)
# expect(is_palindrome("Racecar"), True) # neglect case
# expect(is_palindrome("motor"), False)
# expect(is_palindrome("a"), True)
# expect(is_palindrome("Hi mom!"), False)
# expect(is_palindrome("race car"), False)
# expect(is_palindrome("!level!"), True)
# expect(is_palindrome(""), False)
#
# summary()
# ```
#
# </details>
#
# Now that `is_palindrome` has been designed and tested, we can use it!

# %%
# Write a call to is_palindrome here

# %% [markdown]
# <img style="float: right; width:10%" src="https://lthub.ubc.ca/files/2020/07/iClicker-Cloud-Logo.png">
#
# # iClicker check-in
# How are you doing?  Any trouble keeping up?
#
# <!-- formatting: add two spaces at end of line to force linebreak -->
#   A. 💪 Easy-peasy... you can go faster
#   B. 👍 Yup, I got this
#   C. 😕 I might have missed a bit here or there
#   D. 😟 Hmm, something's not working right
#   E. 😵 I have no idea what's going on
#
# ---
